# %%
import numpy as np
import tensorflow as tf
from keras.datasets import fashion_mnist
from keras.datasets import boston_housing

# %%
(train_data, train_label), (test_data, test_label) = tf.keras.datasets.boston_housing.load_data()

# %%
with tf.Graph().as_default() as g:
    inputs = tf.placeholder(shape = [None, 13], dtype=tf.float32)
    labels = tf.placeholder(shape = [None], dtype=tf.float32)
    
    h1 = tf.keras.layers.Dense(64, activation=tf.nn.relu)(inputs)
    h2 = tf.keras.layers.Dense(16, activation=tf.nn.relu)(h1)
    output = tf.keras.layers.Dense(1, activation=None)(h2)
    
    loss = tf.reduce_mean(
        tf.keras.losses.mean_squared_error(labels, output))
    
    optim = tf.train.GradientDescentOptimizer(learning_rate=1e-6)
    train_op = optim.minimize(loss)

# %%
with tf.Session(graph=g) as sess:
    sess.run(tf.global_variables_initializer())
    batch_size = 32
    for epoch in range(200):
        order = np.argsort(np.random.random(train_label.shape))
        #np.argsort 返回元素从小到大排列的索引
        train_data = train_data[order]
        train_label = train_label[order]
        
        res_train_losses = []
        for i in range(train_label.shape[0] // batch_size):
            start = i * batch_size
            end = (i + 1) * batch_size
            res_train_loss, _ = sess.run([loss, train_op],
                                        feed_dict={inputs: train_data[start: end],
                                                  labels: train_label[start: end]})
            res_train_losses.append(res_train_loss)
        res_val_loss = sess.run(loss,
                               feed_dict={inputs: test_data,
                                         labels: test_label})
        print('epoch %3d, train loss %2.4f, val loss %2.4f' %
              (epoch, res_train_loss, np.mean(res_train_losses)))
# Out:
# epoch   0, train loss 192.5916, val loss 1064.0205
# epoch   1, train loss 127.4538, val loss 115.9345
# epoch   2, train loss 105.5392, val loss 105.7991
# epoch   3, train loss 134.2580, val loss 98.9156
# epoch   4, train loss 73.2423, val loss 100.0968
# epoch   5, train loss 107.7323, val loss 96.5133
# epoch   6, train loss 162.8922, val loss 95.7645
# epoch   7, train loss 115.4944, val loss 94.0442
# epoch   8, train loss 42.0084, val loss 92.7457
# epoch   9, train loss 90.5491, val loss 95.4840
# epoch  10, train loss 64.5613, val loss 90.3308
# epoch  11, train loss 81.4572, val loss 93.0038
# epoch  12, train loss 139.7823, val loss 91.1609
# epoch  13, train loss 82.6883, val loss 93.9087
# epoch  14, train loss 87.5318, val loss 92.5027
# epoch  15, train loss 87.4812, val loss 88.9392
# epoch  16, train loss 67.8064, val loss 93.1100
# epoch  17, train loss 41.6663, val loss 88.7609
# epoch  18, train loss 73.7948, val loss 93.0179
# epoch  19, train loss 122.2945, val loss 93.4974
# epoch  20, train loss 61.4650, val loss 91.0010
# epoch  21, train loss 67.1694, val loss 85.5669
# epoch  22, train loss 77.8301, val loss 91.4641
# epoch  23, train loss 73.5370, val loss 91.8459
# epoch  24, train loss 78.3951, val loss 89.5731
# epoch  25, train loss 72.7477, val loss 88.4999
# epoch  26, train loss 80.5663, val loss 91.7519
# epoch  27, train loss 91.0198, val loss 88.8473
# epoch  28, train loss 90.8715, val loss 89.7793
# epoch  29, train loss 122.0172, val loss 90.8246
# epoch  30, train loss 67.0761, val loss 89.1893
# epoch  31, train loss 83.2292, val loss 88.8877
# epoch  32, train loss 77.4496, val loss 92.4026
# epoch  33, train loss 71.7386, val loss 89.8446
# epoch  34, train loss 96.2615, val loss 90.9840
# epoch  35, train loss 68.7698, val loss 90.2515
# epoch  36, train loss 64.8817, val loss 90.4616
# epoch  37, train loss 67.2772, val loss 90.9069
# epoch  38, train loss 92.2243, val loss 89.8404
# epoch  39, train loss 150.2333, val loss 90.6975
# epoch  40, train loss 75.6913, val loss 86.3008
# epoch  41, train loss 136.7107, val loss 91.5430
# epoch  42, train loss 114.9562, val loss 90.5362
# epoch  43, train loss 76.7737, val loss 88.4377
# epoch  44, train loss 54.8294, val loss 88.7523
# epoch  45, train loss 93.0652, val loss 88.8971
# epoch  46, train loss 97.6349, val loss 89.8185
# epoch  47, train loss 105.6796, val loss 90.3771
# epoch  48, train loss 49.0833, val loss 90.2285
# epoch  49, train loss 128.2166, val loss 88.4157
# epoch  50, train loss 104.0238, val loss 90.9556
# epoch  51, train loss 101.4617, val loss 89.3958
# epoch  52, train loss 71.1950, val loss 87.4325
# epoch  53, train loss 77.0186, val loss 87.5145
# epoch  54, train loss 100.6208, val loss 86.6616
# epoch  55, train loss 63.6353, val loss 86.8481
# epoch  56, train loss 111.1253, val loss 92.0735
# epoch  57, train loss 48.3736, val loss 89.4603
# epoch  58, train loss 67.2417, val loss 91.4273
# epoch  59, train loss 69.1862, val loss 87.0280
# epoch  60, train loss 79.3335, val loss 86.2015
# epoch  61, train loss 58.5601, val loss 86.1086
# epoch  62, train loss 74.0399, val loss 89.0759
# epoch  63, train loss 101.3615, val loss 88.0750
# epoch  64, train loss 40.6346, val loss 90.2566
# epoch  65, train loss 68.7910, val loss 88.3442
# epoch  66, train loss 57.0559, val loss 90.0968
# epoch  67, train loss 83.4988, val loss 84.1887
# epoch  68, train loss 101.8754, val loss 89.6701
# epoch  69, train loss 80.3157, val loss 89.3934
# epoch  70, train loss 43.1418, val loss 89.0316
# epoch  71, train loss 51.5322, val loss 83.6470
# epoch  72, train loss 83.7345, val loss 83.6901
# epoch  73, train loss 96.2607, val loss 89.0086
# epoch  74, train loss 111.1234, val loss 89.5099
# epoch  75, train loss 55.9734, val loss 91.1490
# epoch  76, train loss 110.7813, val loss 89.9867
# epoch  77, train loss 74.6296, val loss 87.1416
# epoch  78, train loss 133.5283, val loss 91.4830
# epoch  79, train loss 61.1287, val loss 88.3639
# epoch  80, train loss 87.4169, val loss 84.8863
# epoch  81, train loss 71.0512, val loss 91.7569
# epoch  82, train loss 131.1837, val loss 89.1351
# epoch  83, train loss 72.4090, val loss 87.9089
# epoch  84, train loss 77.6209, val loss 82.8767
# epoch  85, train loss 50.7551, val loss 84.3327
# epoch  86, train loss 121.3651, val loss 87.4895
# epoch  87, train loss 88.5252, val loss 86.1841
# epoch  88, train loss 85.3572, val loss 89.1799
# epoch  89, train loss 121.1698, val loss 90.5113
# epoch  90, train loss 103.2383, val loss 89.3580
# epoch  91, train loss 60.5986, val loss 87.0478
# epoch  92, train loss 71.2927, val loss 89.6168
# epoch  93, train loss 65.2088, val loss 89.0283
# epoch  94, train loss 44.9781, val loss 87.7726
# epoch  95, train loss 115.4939, val loss 88.6097
# epoch  96, train loss 69.4658, val loss 85.2287
# epoch  97, train loss 48.6945, val loss 85.9694
# epoch  98, train loss 116.5383, val loss 89.6759
# epoch  99, train loss 106.3069, val loss 91.0899
# epoch 100, train loss 92.9964, val loss 89.8876
# epoch 101, train loss 89.0227, val loss 91.0520
# epoch 102, train loss 93.8430, val loss 90.3904
# epoch 103, train loss 102.2826, val loss 92.1236
# epoch 104, train loss 57.0848, val loss 89.1066
# epoch 105, train loss 108.2756, val loss 89.5178
# epoch 106, train loss 48.9625, val loss 86.2493
# epoch 107, train loss 125.5909, val loss 90.5475
# epoch 108, train loss 57.7116, val loss 86.9057
# epoch 109, train loss 56.5008, val loss 88.7004
# epoch 110, train loss 103.0600, val loss 89.6170
# epoch 111, train loss 62.3200, val loss 84.4683
# epoch 112, train loss 92.0096, val loss 84.2264
# epoch 113, train loss 69.8480, val loss 90.3183
# epoch 114, train loss 58.1850, val loss 77.7613
# epoch 115, train loss 109.1450, val loss 89.8237
# epoch 116, train loss 75.3010, val loss 89.8633
# epoch 117, train loss 85.1472, val loss 88.2013
# epoch 118, train loss 108.9810, val loss 88.5473
# epoch 119, train loss 103.6374, val loss 86.3241
# epoch 120, train loss 79.7244, val loss 87.7658
# epoch 121, train loss 74.5661, val loss 87.1508
# epoch 122, train loss 83.0251, val loss 83.1028
# epoch 123, train loss 133.8377, val loss 87.3193
# epoch 124, train loss 100.9095, val loss 90.4468
# epoch 125, train loss 90.3637, val loss 85.8869
# epoch 126, train loss 130.0847, val loss 86.1914
# epoch 127, train loss 83.2949, val loss 87.2633
# epoch 128, train loss 119.9278, val loss 89.6418
# epoch 129, train loss 81.4772, val loss 86.9117
# epoch 130, train loss 75.7849, val loss 90.8662
# epoch 131, train loss 77.1723, val loss 88.7084
# epoch 132, train loss 96.6460, val loss 88.9529
# epoch 133, train loss 100.5965, val loss 88.9271
# epoch 134, train loss 46.2602, val loss 89.8023
# epoch 135, train loss 112.9158, val loss 92.0638
# epoch 136, train loss 97.9585, val loss 89.5347
# epoch 137, train loss 63.3417, val loss 88.3464
# epoch 138, train loss 79.2120, val loss 88.5171
# epoch 139, train loss 66.7202, val loss 91.1125
# epoch 140, train loss 102.5307, val loss 87.3578
# epoch 141, train loss 52.5593, val loss 88.1113
# epoch 142, train loss 69.2650, val loss 89.9220
# epoch 143, train loss 34.9390, val loss 87.3361
# epoch 144, train loss 66.0903, val loss 90.6685
# epoch 145, train loss 87.3502, val loss 90.7902
# epoch 146, train loss 98.6001, val loss 86.9486
# epoch 147, train loss 108.7770, val loss 90.9028
# epoch 148, train loss 119.7942, val loss 90.3553
# epoch 149, train loss 129.7856, val loss 89.9883
# epoch 150, train loss 106.7661, val loss 89.9580
# epoch 151, train loss 69.7652, val loss 84.1601
# epoch 152, train loss 100.2687, val loss 86.4648
# epoch 153, train loss 59.9454, val loss 89.6520
# epoch 154, train loss 85.7238, val loss 88.9710
# epoch 155, train loss 100.3685, val loss 88.2936
# epoch 156, train loss 100.3017, val loss 89.6021
# epoch 157, train loss 80.2203, val loss 89.9908
# epoch 158, train loss 95.9637, val loss 88.5577
# epoch 159, train loss 99.5741, val loss 88.7992
# epoch 160, train loss 106.8838, val loss 86.9682
# epoch 161, train loss 68.5938, val loss 88.9459
# epoch 162, train loss 54.7733, val loss 89.9600
# epoch 163, train loss 73.3646, val loss 85.6753
# epoch 164, train loss 86.2471, val loss 87.8451
# epoch 165, train loss 69.4261, val loss 89.5934
# epoch 166, train loss 87.1094, val loss 88.8467
# epoch 167, train loss 78.1087, val loss 89.9308
# epoch 168, train loss 136.5034, val loss 86.4973
# epoch 169, train loss 104.4056, val loss 86.9720
# epoch 170, train loss 97.7267, val loss 87.6842
# epoch 171, train loss 89.0574, val loss 86.5203
# epoch 172, train loss 69.1927, val loss 90.7295
# epoch 173, train loss 110.0594, val loss 87.6347
# epoch 174, train loss 78.5072, val loss 89.2631
# epoch 175, train loss 91.9422, val loss 90.9084
# epoch 176, train loss 143.9398, val loss 86.1056
# epoch 177, train loss 69.5033, val loss 89.5648
# epoch 178, train loss 142.4673, val loss 88.7664
# epoch 179, train loss 61.6347, val loss 88.5593
# epoch 180, train loss 68.2653, val loss 88.2294
# epoch 181, train loss 56.8711, val loss 87.5349
# epoch 182, train loss 74.4987, val loss 86.4039
# epoch 183, train loss 75.1986, val loss 89.0329
# epoch 184, train loss 80.2917, val loss 88.1001
# epoch 185, train loss 56.9676, val loss 87.2994
# epoch 186, train loss 78.8871, val loss 88.0376
# epoch 187, train loss 141.3201, val loss 88.0841
# epoch 188, train loss 45.7848, val loss 87.2912
# epoch 189, train loss 55.2947, val loss 89.4251
# epoch 190, train loss 131.5715, val loss 87.3896
# epoch 191, train loss 126.6099, val loss 84.1144
# epoch 192, train loss 136.2452, val loss 89.3969
# epoch 193, train loss 78.6820, val loss 87.7750
# epoch 194, train loss 81.7456, val loss 86.7168
# epoch 195, train loss 221.9467, val loss 89.5318
# epoch 196, train loss 78.2812, val loss 90.8637
# epoch 197, train loss 117.8290, val loss 86.8136
# epoch 198, train loss 51.4890, val loss 90.9597
# epoch 199, train loss 119.1983, val loss 85.8023
